# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from extract_data import ExtractData
from clean_data import CleanData

# %%
cleaner = CleanData()
extracter = ExtractData()

# %%
train_df = extracter.read_csv('../data/train.csv')
test_df = extracter.read_csv('../data/test.csv')
store_df = extracter.read_csv('../data/store.csv')
sample_df = extracter.read_csv('../data/sample_submission.csv')
# Out:
# /home/tina/Desktop/Pharmaceutical-Sales-Prediction/scripts/extract_data.py:67: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(csv_file)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %%
train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41077 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
test_df.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      41088 non-null  int64
#  1   Sales   41088 non-null  int64
# dtypes: int64(2)
# memory usage: 642.1 KB

# %%
sample_df.head()
# Out:
#    Id  Sales
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train_store = cleaner.join_dataframes(train_df, store_df, 'Store', 'left')
test_store = cleaner.join_dataframes(test_df, store_df, 'Store', 'left')

# %%
train_store.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %%
train_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
test_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         41088 non-null  int64
#  1   Store                      41088 non-null  int64
#  2   DayOfWeek                  41088 non-null  int64
#  3   Date                       41088 non-null  object
#  4   Open                       41077 non-null  float64
#  5   Promo                      41088 non-null  int64
#  6   StateHoliday               41088 non-null  object
#  7   SchoolHoliday              41088 non-null  int64
#  8   StoreType                  41088 non-null  object
#  9   Assortment                 41088 non-null  object
#  10  CompetitionDistance        40992 non-null  float64
#  11  CompetitionOpenSinceMonth  25872 non-null  float64
#  12  CompetitionOpenSinceYear   25872 non-null  float64
# ...

# %%
test_store.head()
# Out:
#      Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0     1      1          4  2015-09-17   1.0      1            0
# 1   857      1          3  2015-09-16   1.0      1            0
# 2  1713      1          2  2015-09-15   1.0      1            0
# 3  2569      1          1  2015-09-14   1.0      1            0
# 4  3425      1          7  2015-09-13   0.0      0            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              0         c          a               1270.0
# 1              0         c          a               1270.0
# 2              0         c          a               1270.0
# 3              0         c          a               1270.0
# 4              0         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# ...

# %%
#convert the date to date time
train_store = cleaner.convert_to_datetime(train_store, 'Date')
test_store = cleaner.convert_to_datetime(test_store, 'Date')

# %%
train_store.set_index('Date', inplace=True)
test_store.set_index('Date', inplace=True)

# %%
train_store.to_csv('../data/train_store.csv', index=True)
test_store.to_csv('../data/test_store.csv', index=True)

# %%
train_df = extracter.read_csv('../data/train_store.csv')
test_df = extracter.read_csv('../data/test_store.csv')

# %%
test_store.isna().sum()
# Out:
# Id                               0
# Store                            0
# DayOfWeek                        0
# Open                            11
# Promo                            0
# StateHoliday                     0
# SchoolHoliday                    0
# StoreType                        0
# Assortment                       0
# CompetitionDistance             96
# CompetitionOpenSinceMonth    15216
# CompetitionOpenSinceYear     15216
# Promo2                           0
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# PromoInterval                17232
# dtype: int64

# %%
train_store.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
missing_df = train_df[['PromoInterval', 'Promo2SinceYear', 'Promo2SinceWeek', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionDistance', 'Open']]
missing_df.head(10)
# Out:
#   PromoInterval  Promo2SinceYear  Promo2SinceWeek  CompetitionOpenSinceMonth  \
# 0           NaN              NaN              NaN                        9.0
# 1           NaN              NaN              NaN                        9.0
# 2           NaN              NaN              NaN                        9.0
# 3           NaN              NaN              NaN                        9.0
# 4           NaN              NaN              NaN                        9.0
# 5           NaN              NaN              NaN                        9.0
# 6           NaN              NaN              NaN                        9.0
# 7           NaN              NaN              NaN                        9.0
# 8           NaN              NaN              NaN                        9.0
# 9           NaN              NaN              NaN                        9.0
#
#    CompetitionOpenSinceYear  CompetitionDistance  Open
# 0                    2008.0               1270.0     1
# ...

# %%
missing = ['Promo2SinceYear', 'Promo2SinceWeek', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'CompetitionDistance']
train_df = cleaner.fill_missing_median(train_df, missing)
test_df = cleaner.fill_missing_median(test_df, missing)

# %%
test_df = cleaner.fill_missing_with_zero(test_df, ['Open'])

# %%
train_df = cleaner.fill_missing_mode(train_df, ['PromoInterval'])
test_df = cleaner.fill_missing_mode(test_df, ['PromoInterval'])

# %%
train_df = cleaner.fill_missing_mode(train_df, ['PromoInterval'])
test_df = cleaner.fill_missing_mode(test_df, ['PromoInterval'])

# %%
train_df.isna().sum()
# Out:
# Date                         0
# Store                        0
# DayOfWeek                    0
# Sales                        0
# Customers                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
test_df.isna().sum()
# Out:
# Date                         0
# Id                           0
# Store                        0
# DayOfWeek                    0
# Open                         0
# Promo                        0
# StateHoliday                 0
# SchoolHoliday                0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %%
train_df.drop('Customers',inplace = True, axis=1)

# %%
train_df.to_csv('../data/cleaned_train.csv', index=True)
test_df.to_csv('../data/cleaned_test.csv', index=True)
